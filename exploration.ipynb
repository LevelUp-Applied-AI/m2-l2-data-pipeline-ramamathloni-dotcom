# %%
import pandas as pd
import matplotlib.pyplot as plt
from pipeline import load_data, clean_data, add_features
# %matplotlib inline

# %%
df = load_data('data/sales_records.csv')
df = clean_data(df)
df = add_features(df)
df.head() # هاي بتعرض لك أول 5 صفوف بشكل جدول مرتب
# Out:
# Loaded 500 records from data/sales_records.csv
# Cleaned data: 500 records
#         date  store_id    product_category  quantity  unit_price  \
# 0 2024-01-01         1  Mobile Accessories      18.0       21.49
# 1 2024-01-02         4           Computing       2.0      485.92
# 2 2024-01-02         5               Audio       8.0       73.07
# 3 2024-01-02         5     Home Appliances      10.0      366.85
# 4 2024-01-03         2     Home Appliances      16.0      192.69
#
#    payment_method  revenue day_of_week
# 0     Credit Card   386.82      Monday
# 1            Cash   971.84     Tuesday
# 2  Mobile Payment   584.56     Tuesday
# 3  Mobile Payment  3668.50     Tuesday
# 4            Cash  3083.04   Wednesday

# %%
# هيك بتشوفي الرسمة فوراً داخل الـ Notebook
df.groupby('product_category')['revenue'].sum().plot(kind='bar', title='Revenue by Category')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              485 non-null    datetime64[ns]
#  1   store_id          500 non-null    int64
#  2   product_category  500 non-null    object
#  3   quantity          500 non-null    float64
#  4   unit_price        500 non-null    float64
#  5   payment_method    500 non-null    object
#  6   revenue           500 non-null    float64
#  7   day_of_week       485 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 31.4+ KB

# %%
df
# Out:
#           date  store_id    product_category  quantity  unit_price  \
# 0   2024-01-01         1  Mobile Accessories      18.0       21.49
# 1   2024-01-02         4           Computing       2.0      485.92
# 2   2024-01-02         5               Audio       8.0       73.07
# 3   2024-01-02         5     Home Appliances      10.0      366.85
# 4   2024-01-03         2     Home Appliances      16.0      192.69
# ..         ...       ...                 ...       ...         ...
# 495 2024-06-27         4     Home Appliances       5.0      372.45
# 496 2024-06-27         3  Mobile Accessories      17.0       63.36
# 497 2024-06-27         2         Electronics      18.0      565.81
# 498 2024-06-28         5               Audio       1.0      145.23
# 499 2024-06-28         3         Electronics      19.0      524.77
#
#      payment_method   revenue day_of_week
# 0       Credit Card    386.82      Monday
# 1              Cash    971.84     Tuesday
# ...
